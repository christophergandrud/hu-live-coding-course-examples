# %% [markdown]
# # Test Tabula Python for Extracting Python Tables

# %% [markdown]
# # Set up
#
# Install tabula
#
# ```
# pip install tabula-py
# ```

# %% [markdown]
# ## Extract a Table

# %%
import tabula

# %%
# Example from tabula docs
df = tabula.read_pdf("https://github.com/tabulapdf/tabula-java/raw/master/src/test/resources/technology/tabula/arabic.pdf")
# Out:
# 'pages' argument isn't specified.Will extract only from page 1 by default.

# %%
df = tabula.read_pdf("https://www.visionofhumanity.org/wp-content/uploads/2020/10/GPI_2020_web.pdf", pages=10, user_agent='Mozilla/5.0')

# %%
df[0]
# Out:
#    RANK         COUNTRY  SCORE CHANGE RANK.1         COUNTRY SCORE  \
# 0     1         Iceland  1.078           29                Poland
# 1     2     New Zealand  1.198           30               Estonia
# 2     3        Portugal  1.247           31                 Italy
# 3     4         Austria  1.275           32            Costa Rica
# 4     5         Denmark  1.283           33              Botswana
# 5     6          Canada  1.298           34                Latvia
# 6     7       Singapore  1.321           35               Uruguay
# 7     8  Czech Republic  1.337     1     36             Lithuania
# 8     9           Japan  1.360     2     37                Taiwan
# 9    10     Switzerland  1.366           38                 Spain
# 10   11        Slovenia  1.369     2    =39                Kuwait
# 11   12         Ireland  1.375          =39              Mongolia
# 12   13       Australia  1.386           41  United Arab Emirates
# ...
